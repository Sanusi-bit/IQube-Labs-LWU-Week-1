# %%
import os
import pandas as pd

# %%
tweet_count = 20000
text_query = "#ENDSARS"
since_date = "2020-06-01"
until_date = "2021-02-28"

# %%
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-5b9f27354d1b> in <module>
# ----> 1 os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
#
# KeyboardInterrupt:

# %%
tweets_df2 = pd.read_json('text-query-tweets.json', lines=True)

# %%
tweets_df2.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/noxyplanet/status/13658133...
# 1  https://twitter.com/BlendNg/status/13658130500...
# 2  https://twitter.com/Omzyoflagos/status/1365812...
# 3  https://twitter.com/_Allison_Gloria/status/136...
# 4  https://twitter.com/warner_time1/status/136581...
#
#                        date  \
# 0 2021-02-27 23:57:28+00:00
# 1 2021-02-27 23:56:21+00:00
# 2 2021-02-27 23:56:07+00:00
# 3 2021-02-27 23:53:24+00:00
# 4 2021-02-27 23:51:00+00:00
#
#                                              content  \
# 0  The Rivers State GOC, commander of the 6th Div...
# 1  #EndSars: FG Created Over N25B To Supplement T...
# 2  I repeat again this @MBuhari regime has shown ...
# 3  Bandits actions are being justified as mere ac...
# 4  #EndSARS #EndBadGoveranceInNigeria https://t.c...
#
#                                      renderedContent                   id  \
# 0  The Rivers State GOC, commander of the 6th Div...  1365813330435330048
# 1  #EndSars: FG Created Over N25B To Supplement T...  1365813050046054404
# 2  I repeat again this @MBuhari regime has shown ...  1365812992143728643
# 3  Bandits actions are being justified as mere ac...  1365812309298475010
# 4  #EndSARS #EndBadGoveranceInNigeria twitter.com...  1365811702240055296
#
#                                                 user  \
# 0  {'username': 'noxyplanet', 'displayname': 'Chi...
# 1  {'username': 'BlendNg', 'displayname': 'BlendN...
# 2  {'username': 'Omzyoflagos', 'displayname': 'Om...
# 3  {'username': '_Allison_Gloria', 'displayname':...
# 4  {'username': 'warner_time1', 'displayname': 'a...
#
#                                             outlinks  \
# 0                                                 []
# 1  [https://blendng.com/endsars-fg-created-over-n...
# 2                                                 []
# 3                                                 []
# 4  [https://twitter.com/PeterROCK_/status/1365421...
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0                         []           0             0  ...           0
# 1  [https://t.co/GYjC2xlCgw]           0             0  ...           0
# 2                         []           2             0  ...           0
# 3                         []           0             1  ...           0
# 4  [https://t.co/KjoqAs7U2h]           0             1  ...           0
#
#         conversationId  lang  \
# 0  1365813330435330048    en
# 1  1365813050046054404    en
# 2  1365812992143728643    en
# 3  1365812309298475010    en
# 4  1365811702240055296   und
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="https://revive.social/" rel="nofollow...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                              sourceUrl          sourceLabel  \
# 0  http://twitter.com/download/android  Twitter for Android
# 1               https://revive.social/    Revive Social App
# 2   http://twitter.com/download/iphone   Twitter for iPhone
# 3   http://twitter.com/download/iphone   Twitter for iPhone
# 4  http://twitter.com/download/android  Twitter for Android
#
#                                                media retweetedTweet  \
# 0  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 1                                               None            NaN
# 2                                               None            NaN
# 3  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...            NaN
# 4                                               None            NaN
#
#                                          quotedTweet  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'url': 'https://twitter.com/PeterROCK_/status...
#
#                                       mentionedUsers
# 0  [{'username': 'General_Somto', 'displayname': ...
# 1                                               None
# 2  [{'username': 'MBuhari', 'displayname': 'Muham...
# 3                                               None
# 4                                               None
#
# [5 rows x 21 columns]

# %%
tweets_df2.shape
# Out:
# (16692, 21)

# %%
df_obj=tweets_df2[tweets_df2.duplicated(['renderedContent'])]

# %%
df_obj
# Out:
#                                                      url  \
# 104    https://twitter.com/xpoet1/status/136577764248...
# 141    https://twitter.com/doyinnaj/status/1365768332...
# 156    https://twitter.com/iam_Daposh/status/13657654...
# 180    https://twitter.com/PelMedic/status/1365758904...
# 181    https://twitter.com/tdpel/status/1365758901099...
# ...                                                  ...
# 16618  https://twitter.com/royal_adejoh/status/136277...
# 16640  https://twitter.com/NdidiUwechue/status/136277...
# 16659  https://twitter.com/Spotweefy/status/136277224...
# 16664  https://twitter.com/Smart_feelin/status/136277...
# 16673  https://twitter.com/Obieze__/status/1362770991...
#
#                            date  \
# 104   2021-02-27 21:35:39+00:00
# 141   2021-02-27 20:58:39+00:00
# 156   2021-02-27 20:47:15+00:00
# 180   2021-02-27 20:21:12+00:00
# 181   2021-02-27 20:21:11+00:00
# ...                         ...
# 16618 2021-02-19 14:51:00+00:00
# 16640 2021-02-19 14:43:00+00:00
# 16659 2021-02-19 14:33:17+00:00
# 16664 2021-02-19 14:31:28+00:00
# 16673 2021-02-19 14:28:18+00:00
#
#                                                  content  \
# 104                                             #EndSARS
# 141                                             #EndSARS
# 156                                             #EndSARS
# 180    #ENDSARS: LAGOS PAYS N20 MILLION NAIRA COMPENS...
# 181    #ENDSARS: LAGOS PAYS N20 MILLION NAIRA COMPENS...
# ...                                                  ...
# 16618                   #EndSARS https://t.co/NFhZhuzQpT
# 16640  #End1999Constitution #PartiesCloseShopNow #End...
# 16659  4 Instance by 2Baba, VIP #EndSARS https://t.co...
# 16664  @channelstv Please I am teaching people psycho...
# 16673  Short let‼️‼️‼️\n\n3bedroom penthouse with roo...
#
#                                          renderedContent                   id  \
# 104                                             #EndSARS  1365777642486706180
# 141                                             #EndSARS  1365768332339732480
# 156                                             #EndSARS  1365765462420643841
# 180    #ENDSARS: LAGOS PAYS N20 MILLION NAIRA COMPENS...  1365758904777527297
# 181    #ENDSARS: LAGOS PAYS N20 MILLION NAIRA COMPENS...  1365758901099102208
# ...                                                  ...                  ...
# 16618               #EndSARS twitter.com/SaharaReporter…  1362776704318636034
# 16640  #End1999Constitution #PartiesCloseShopNow #End...  1362774691522351108
# 16659  4 Instance by 2Baba, VIP #EndSARS open.spotify...  1362772249275748352
# 16664  @channelstv Please I am teaching people psycho...  1362771791186427906
# 16673  Short let‼️‼️‼️\n\n3bedroom penthouse with roo...  1362770991399788546
#
#                                                     user  \
# 104    {'username': 'xpoet1', 'displayname': 'Xquisit...
# 141    {'username': 'doyinnaj', 'displayname': 'billy...
# 156    {'username': 'iam_Daposh', 'displayname': 'Kin...
# 180    {'username': 'PelMedic', 'displayname': 'PelMe...
# 181    {'username': 'tdpel', 'displayname': 'TDPel Me...
# ...                                                  ...
# 16618  {'username': 'royal_adejoh', 'displayname': 'S...
# 16640  {'username': 'NdidiUwechue', 'displayname': 'N...
# 16659  {'username': 'Spotweefy', 'displayname': 'Spot...
# 16664  {'username': 'Smart_feelin', 'displayname': '0...
# 16673  {'username': 'Obieze__', 'displayname': 'Obiez...
#
#                                                 outlinks  \
# 104                                                   []
# 141                                                   []
# 156                                                   []
# 180    [https://tdpelmedia.com/endsars-lagos-pays-n20...
# 181    [https://tdpelmedia.com/endsars-lagos-pays-n20...
# ...                                                  ...
# 16618  [https://twitter.com/SaharaReporters/status/13...
# 16640  [https://twitter.com/FreedomFromNgr/status/136...
# 16659  [https://open.spotify.com/track/7FQecMcIQ2oB7d...
# 16664                                                 []
# 16673                                                 []
#
#                      tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 104                           []           0             1  ...           0
# 141                           []           0             0  ...           0
# 156                           []           0             1  ...           0
# 180    [https://t.co/EMZSMKjozo]           0             0  ...           0
# 181    [https://t.co/0cWtrbHB5s]           0             0  ...           0
# ...                          ...         ...           ...  ...         ...
# 16618  [https://t.co/NFhZhuzQpT]           0             2  ...           0
# 16640  [https://t.co/MMOeVhseaU]           0             9  ...           0
# 16659  [https://t.co/s4ckyHkWcd]           0             0  ...           0
# 16664                         []           0             0  ...           0
# 16673                         []           1             1  ...           0
#
#             conversationId  lang  \
# 104    1365777642486706180   und
# 141    1365768332339732480   und
# 156    1365765462420643841   und
# 180    1365758904777527297    en
# 181    1365758901099102208    en
# ...                    ...   ...
# 16618  1362776704318636034   und
# 16640  1362774691522351108   und
# 16659  1362772249275748352    en
# 16664  1362750822128484352    en
# 16673  1362770991399788546    en
#
#                                                   source  \
# 104    <a href="http://twitter.com/download/iphone" r...
# 141    <a href="http://twitter.com/download/iphone" r...
# 156    <a href="http://twitter.com/download/iphone" r...
# 180    <a href="http://publicize.wp.com/" rel="nofoll...
# 181    <a href="http://publicize.wp.com/" rel="nofoll...
# ...                                                  ...
# 16618  <a href="http://twitter.com/download/android" ...
# 16640  <a href="https://mobile.twitter.com" rel="nofo...
# 16659  <a href="https://twitter.com/Baba_BS" rel="nof...
# 16664  <a href="https://mobile.twitter.com" rel="nofo...
# 16673  <a href="http://twitter.com/download/android" ...
#
#                                  sourceUrl          sourceLabel  \
# 104     http://twitter.com/download/iphone   Twitter for iPhone
# 141     http://twitter.com/download/iphone   Twitter for iPhone
# 156     http://twitter.com/download/iphone   Twitter for iPhone
# 180               http://publicize.wp.com/        WordPress.com
# 181               http://publicize.wp.com/        WordPress.com
# ...                                    ...                  ...
# 16618  http://twitter.com/download/android  Twitter for Android
# 16640           https://mobile.twitter.com      Twitter Web App
# 16659          https://twitter.com/Baba_BS         Bots by Baba
# 16664           https://mobile.twitter.com      Twitter Web App
# 16673  http://twitter.com/download/android  Twitter for Android
#
#                                                    media retweetedTweet  \
# 104                                                 None            NaN
# 141                                                 None            NaN
# 156                                                 None            NaN
# 180                                                 None            NaN
# 181                                                 None            NaN
# ...                                                  ...            ...
# 16618                                               None            NaN
# 16640                                               None            NaN
# 16659                                               None            NaN
# 16664                                               None            NaN
# 16673  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...            NaN
#
#                                              quotedTweet  \
# 104                                                 None
# 141                                                 None
# 156                                                 None
# 180                                                 None
# 181                                                 None
# ...                                                  ...
# 16618  {'url': 'https://twitter.com/SaharaReporters/s...
# 16640  {'url': 'https://twitter.com/FreedomFromNgr/st...
# 16659                                               None
# 16664                                               None
# 16673                                               None
#
#                                           mentionedUsers
# 104                                                 None
# 141                                                 None
# 156                                                 None
# 180                                                 None
# 181                                                 None
# ...                                                  ...
# 16618                                               None
# 16640                                               None
# 16659                                               None
# 16664  [{'username': 'channelstv', 'displayname': 'Ch...
# 16673                                               None
#
# [923 rows x 21 columns]

# %%
tweets_df2.drop(df_obj.index, axis=0,inplace=True)

# %%
tweets_df2.shape
# Out:
# (15769, 21)

# %%
# Export dataframe into a CSV
tweets_df2.to_csv('text-query-tweets.csv', sep=',', index=False)
